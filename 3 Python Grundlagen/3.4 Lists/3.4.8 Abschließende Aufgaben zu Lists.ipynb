# %% [markdown]
# # 3.4 Lists
#
# ## 3.4.8 Abschließende Aufgaben zu Lists
#
# In drei abschließenden Aufgaben kannst du das bisher Gelernte praktisch anwenden. Ihre Bearbeitung wird etwa 30-60 Minuten dauern.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>1. Anpassung einer Produktliste</b></font>
#
# 4 Tipps zu dieser Aufgabe findest du weiter unten.
# <br>
#
# Du hast eine Produktliste deines Unternehmens vorliegen. Diese soll umstrukturiert werden.
# <br>
#
# **a)** Die Marke <b>Gluehwurm</b> hat ihre Produktpalette erweitert. Künftig wirst du noch mehr Produkte von ihr anbieten können. Finde mit einer If-Abfrage heraus, ob sich ihr bisher einziges Produkt <b>Gluehwurm Lampe</b> in der Produktliste befindet. Wenn ja, soll es einer neuen Liste für künftige Produkte von <b>Gluehwurm</b> hinzugefügt werden (Stichwort: If-Abfrage).
#
# **b)** In der allgemeinen Liste zu deinen Produkten, <b>products</b>, soll <b>Gluehwurm Lampe</b> nicht mehr erscheinen, da du nun eine extra Liste für  <b>Gluehwurm</b>-Produkte hast. Finde heraus, auf welchem Index sich <b>Gluehwurm Lampe</b> befindet.
#
# **c)** Lösche den Eintrag <b>Gluehwurm Lampe</b> anhand seines Indizes aus der allgemeinen Produktliste. Gib die Produktliste zur Überprüfung aus.
# </div>

# %%
# a)

products = ['AugenBraun Lockenstab', 'Gluehwurm Lampe', 'Sockenfänger Waschmaschine', 'Prof. Weißheit Zahnbürste']

# %%
# b)

# %%
# c)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 1 zur Aufgabe:</b></font> Um einer neuen Liste einen Eintrag hinzuzufügen, muss die Liste zuerst definiert werden.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 2 zur Aufgabe:</b></font> Da die Liste vorerst nur aus einem Produkt bestehen soll, ist erst einmal nichts in ihr enthalten.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 3 zur Aufgabe:</b></font> Die neue Liste brauchst du in jedem Fall, ob das gefragte Produkt in ihr enthalten ist oder nicht. Schließlich werden die neuen Produkte der Marke <b>Gluehwurm</b> sowieso bald eintreffen. Außerdem soll sie über die If-Abfrage hinaus weiterverwendet werden.
#
# Definiere die neue Liste also außerhalb des If-Statements.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 4 zur Aufgabe:</b></font>
#
# Mit welcher Funktion kannst du Werte einer Liste anhängen?
#
# Mit welcher Funktion kannst du den Index eines Listeneintrags herausfinden?
#
# Wie löschst du einen Listeneintrag anhand seines Indizes?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>2. Neue Produktpalette</b></font>
#
# 3 Tipps zu dieser Aufgabe findest du weiter unten.
# Für diese Aufgabe gibt es verschiedene Lösungswege. Wenn du das richtige Ergebnis in der Ausgabe siehst, ist deine Lösung auch richtig.
# <br>
#
# Die neue Produktpalette der Marke "Gluehwurm" ist eingetroffen.
# <br>
#
# **a)** Füge die Liste <b>gluehwurm_extra</b> in die Liste <b>gluehwurm_products</b> ein. Es darf dabei keine Subliste in <b>gluehwurm_products</b> gebildet werden. Gib <b>gluehwurm_products</b> anschließend aus.
#
# **b)** Du hast dir überlegt, dass es sinnvoll wäre, die neue Produktpalette auch in <b>products</b> gespeichert zu haben. Füge <b>gluehwurm_products</b> als Subliste an den sichtbar alphabetisch korrekten Index ein. Gib <b>products</b> aus, um das zu überprüfen.
#
# **c)** Die Subliste zu den Gluehwurm-Produkten ist nicht alphabetisch geordnet. Sortiere diese Subliste. Gib <b>products</b> wieder zur Überprüfung aus.
#
# **d)** Ein Praktikant bei <b>Gluehwurm</b> hat ein Produkt durcheinandergebracht. Wie dir mitgeteilt wird, stellt <b>Gluehwurm</b> gar keine Lesebrillen her, sondern Käsehüllen. Finde den Index von <b>'Gluehwurm Lesebrille'</b> in der Subliste. Ersetze anschließend diesen Eintrag durch <b>'Gluehwurm Käsehülle'</b>. Gib die nun korrigierte und sortierte Liste zu <b>products</b> aus.
#
# **e)** Optional kannst du auch <b>gluehwurm_products</b> korrigieren und sortieren.
#
# </div>

# %%
# a)

products = ['AugenBraun Lockenstab', 'Sockenfang Waschmaschine', 'Weißheit Zahnbürste']

gluehwurm_extra = ['Gluehwurm Lampe']

gluehwurm_products = ['Gluehwurm Lesebrille', 'Gluehwurm Fernseher', 'Gluehwurm USB-Kabel']

# %%
# b)

# %%
# c)

# %%
# d)

# %%
# e)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 1 zur Aufgabe:</b></font> Einige Funktionen bilden Sublisten beim Einfügen einer Liste in eine Liste, einige nicht.
#
# Welche waren das noch?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 2 zur Aufgabe:</b></font> Um eine Subliste zu sortieren, nutze die Index-Notation.
#
# Schreibe den Index der Subliste hinter die Liste und wende darauf die Sortierungsfunktion an.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>Tipp 3 zur Aufgabe:</b></font> Auch den Index eines Elements in einer Subliste findest du, indem du in der Subliste suchst, also die Subliste über ihren Index hinter der Listenvariable anwählst.
#
# Darauf wendest du mit dem Punkt-Operator die Funktion an, die den Index des Listeneintrags findet.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size="3"><b>3. Durchschnittsbewertung</b></font>
# <br>
#
# Studierende deiner Uni haben ProfessorInnen Noten von 1 (am besten) bis 6 (am schlechtesten) gegeben. Es wurden 5 ProfessorInnen von 5 Studierenden bewertet. Die Ergebnisse jedes/r Professors/in sind jeweils in einer Subliste in der Liste <b>ranking</b> gespeichert.
# Wie hoch ist der beste Durchschnitt?
# <br>
#
# Damit du den Durchschnitt berechnen kannst, wurde das Modul <b>statistics</b> bereits für dich importiert. Mit <b>statistics.mean()</b> ist der Durchschnitt einer Liste berechenbar.
# In der ersten Code-Zelle unten siehst du ein Beispiel zur Berechnung.
# <br>
#
# **Aufgabe**
#
# **a)** Erstelle eine neue Liste und füge dieser den Durchschnitt jeder Subliste hinzu. Gib die Liste aus.
#
# **b)** Verwende anschließend eine Funktion, um den besten Durchschnitt auszugeben.
# </div>

# %%
import statistics

ranking = [[2,2,3,1,3], [1,4,3,2,2], [4,3,5,3,2], [2,3,1,1,2], [3,2,2,4,1]]

statistics.mean(ranking[0])

# %%
# a)

# %%
# b)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Herzlichen Glückwunsch!</b> Hiermit hast du das Kapitel "3.4 Lists" abgeschlossen.
#
# Du hast nicht nur die wichtigsten Funktionen für Listen kennengelernt, sondern auch die wichtigsten Funktionen für iterierbare Objekte allgemein!
#
# Du kennst die Vorteile von Listen, kannst sie erweitern, Einträge ändern und löschen.
#
# Außerdem kannst du Subsets von Listen erstellen und bist geübt im Umgang mit verschachtelten Listen.
#
# Darüber hinaus hast du sogar gelernt, was es mit flachen und tiefen Kopien auf sich hat und bist damit von vornherein gewappnet gegen ungewollte Überschreibungsfehler.
#
# Im nächsten Kapitel lernst du den Collection-Type Dictionary im Detail kennen.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Das kannst du aus dem Kapitel "3.4 Lists" mitnehmen:</h3>
#
# * **List**
#     * gehört zu Pythons **Collections**
#     * ist eine übergeordnete Datenstruktur zum Speichern verschiedener Datentypen
#     * ist Python-intern der Datentyp **list**
#     * eine leere Liste besteht aus zwei eckigen Klammern: ``[]``
#     * kann einer Variable zugewiesen werden (und wird das für gewöhnlich auch): ``list example = []``
#     * Werte einer Liste werden mit einem Komma bzw. optional zusätzlich einem Leerzeichen getrennt
#         * so: ``list example = ['Nummer 0','Nummer 1','Nummer 2']``
#         * oder so: `list example = ['Nummer 0', 'Nummer 1', 'Nummer 2']``
# <br>
# * **Vorteile von Listen**
#     * kompakte Speicherung von Daten
#     * Verwendung verschiedener Datentypen in einer Liste
#     * Verwendung aller Datentypen als Listeneinträge
#     * beliebige Verkürzung und Erweiterung möglich
#     * unzählige built-in Functions zur vereinfachten Bearbeitung von Listen verfügbar
#     * gleichzeitiges Bearbeiten aller Listeneinträge möglich
#     * Aufteilen von Listen zu Sublisten sowie die Vereinigung mehrerer Listen zu einer Liste über Indexierung/Slicing/Splitten realisierbar
#     * Erstellung einer Tabelle aus einer Liste möglich
#     * **Hauptvorteil: Listen sind flexibel**
# <br>
# * **Indexierung von Listen**
#     * beginnt, analog zu Strings, bei Index 0
#     * endet, analog zu Strings mit dem Index -1
#     * Syntax: <font color = green>liste[ab inklusive hier slicen:bis exklusive hier slicen:Schritte]</font>
#     * Syntax laut Python-Dokumentation: <font color = green>liste[start:stop:step]</font>
#     * alle Listeneinträge ausgeben: ``lst[:]``
#     * Listeneinträge durch Angabe von Schritten überspringen:
#         * Beispiel: ``lst = [1,2,3,4,5,6,7,8,9]``
#         * ``lst[1:6:2]`` => Output: [2, 4, 6]
#         * denn im Beispiel wird jeder 2. Eintrag von Eintrag 2 bis Eintrag 6 ausgegeben (an Index 6 liegt der 7. Eintrag, der exklusive ist)
#     * eine komplette Liste rückwärts ausgeben: ``lst[::-1]``
#     * jeden 2. Listeneintrag aus einer umgedrehten Liste ausgeben: ``lst[::-2]``
#     * Achtung: <b>list</b> ist der Python-interne Name für Listen und gehört zu den reservierten Namen - verwende <b>list</b> deshalb **nie** zur Benennung einer Liste, denn das führt zu Fehlern
#     * für eine sinnvolle Splittung sollte der Indexwert vor dem Doppelpunkt stets kleiner als der nach dem Doppelpunkt sein, das Ergebnis ist sonst eine leere Liste (oder ein leerer String: <font color = green>liste[>:>:step]</font>
# <br>
# * **iterierbare Objekte**
#     * sind alle Objekte, deren Werte nacheinander durchlaufen werden können
#     * zu ihnen gehören Strings und alle Datenstrukturen/Collection-Typen
# <br>
# * **Funktionen für iterierbare Objekte**
#     * ``len()`` zur Ermittlung der Anzahl aller Elemente, z.B.: ``len([3,2,1])`` => Output: 3
#     * ``min()`` zur Ermittlung des niedrigsten Wertes eines Iterables, z.B.: ``min([3,2,1])`` => Output: 1
#         * hat 2 verschiedene Syntaxen (nicht mischbar) mit zusätzlichen, optionalen Parametern:
#             * Syntax 1: <font color = green>min(iterable, default=object, key=None)</font>
#                 * <b>default</b>: ruft ein Objekt auf, wenn die übergebene Liste leer ist - ohne default: <font color = darkred>ValueError</font>
#                 * <b>key</b>: vergleicht die Werte auf ihr Minimum hin anhand der übergebenen Funktion
#             * Syntax 2: <font color = green>min(arg1, arg2, *args,  key=None)</font>
#                 * <b>arg/args</b>: 2 oder beliebig viele Iterables werden auf ihr Minimum hin verglichen
#                 * <b>key</b>: siehe die Beschreibung zu key in Syntax 1
#                 * Rückgabewert ist das gesamte Iterable, welches das Minimum enthält
#     * ``max()`` zur Ermittlung des höchsten Wertes, z.B.: ``max([3,2,1])`` => Output: 3
#         * auch ``max()`` hat 2 verschiedene Syntaxen, welche analog zu den 2 Syntaxen von ``min()`` funktionieren, nur das auf das Maximum hin verglichen wird
#     * ``iter()`` zur Umwandlung in einen Iterator, z.B.: ``iter([3,2,1])``
#         * in Kombination mit ``next()`` zum Nacheinander-Anwählen der Objekte, z.B.: ``next(iterator)``
#     * ``list()`` zur Erstellung einer Liste, z.B.: ``list('string')``
#         * ``zip()`` zur Vereinigung mehrerer Listen (oder anderen Datenstrukturen) zu einer neuen
#         * Syntax: <font color = green>zip(\*iterables)</font> => beliebig viele (\*) Iterables werden mit einem Komma in den Funktionsklammern getrennt
#         * die Einträge der vereinten Ergebnisliste bestehen aus Tupeln, die jeweils die ersten, dann die zweiten, dritten usw. Listeneinträge der einzelnen Listen vereinen
#         * für die Umwandlung zu einer Liste aus dem durch ``zip()`` entstandenen Zip-Objekt ist ``list()`` erforderlich
#         * Beispiel:
#             * ``lst1 = ['A', 'B', 'C']``
#             * ``lst2 = ['D', 'E', 'F']``
#             * ``lst_combined = list(zip(lst1, lst2))``
#             * Output über ``print(lst_combined)`` => [('A', 'D'), ('B', 'E'), ('C', 'F')]
#         * Unzippe die Tuple aus einer gezippten Liste (innerhalb einer Liste) mit Angabe des Asterisks (Sternchens) ``list(zip(*tuplelist))``
#     * ``sorted()`` zum Sortieren, z.B.: ``sorted([3,2,1])`` => Output: [1,2,3]
#         * sortiert in aufsteigender Reihenfolge - in **ascending Order**
#         * sortiert Iterables
#         * Rückgabewert ist immer eine Liste
#         * Syntax: <font color = green>sorted(iterierbaresObjekt, key=None, reverse=False)</font>
#         * Anwendung einer Funktion in ``sorted()``, z.B.: ``sorted(str.split())`` => splittet den String an seinen Leerezeichen und sortiert die einzelnen Wörter
#         * Anwendung einer Funktion mittels **key**, z.B.: ``sorted(iterable, key=len)`` => sortiert die Strings in der übergebenen Liste nach Länge
#         * Sortierung in absteigender Reihenfolge - in **descending Order** -  mit **reverse**, z.B.: ``sorted(iterable, reverse=True)``
#         * reverse=True entspricht [::-1]
#         * Sortierung nach Stringlänge und rückwärts, z.B.: ``sorted(iterable, key=len, reverse=True)``
#         * ``sorted()`` ist ein stabiler Sortieralgorithmus, der **nicht** in-place sortiert
#         * Werte müssen gleichen Datenyps sein, sonst ist kein Vergleich zum Sortieren möglich, doch Floats und Integers werden verglichen
#         * nicht zu verwechseln mit ``.sort()``, welches ein instabiler Sortieralgorithmus ist, der in-place sortiert und nur Listen sortieren kann
#     * ``del`` ist ein Statement/Keyword - keine Funktion - zum Löschen von deklarierten Objekten jeglicher Art, z.B.: ``del x``
#         * zum Löschen von Listeneinträgen an einem bestimmten Index, z.B.: ``del lst[0]`` => löscht den Eintrag an Index 0
# <br>
# * **über Algorithmen**
#     * ein stabiler Sortier-Algorithmus behält die Anordnung gleicher Elemente bei
#     * ein in-place Algorithmus überschreibt das übergebene Objekt, z.B. eine Originalliste wird überschrieben
# <br>
# * **Collection-Typen/Datenstrukturen neben List**
#     * <b>Dictionary</b>
#         * Beispiel:
#             * ``dict_example = {'name': 'Ben Bender', 'Stadt': 'Berlin', 'Guthaben': 144.77}``
#         * wie eine Liste kann ein Dictionary verschiedene Datentypen beinhalten
#         * wie eine Liste ist ein Dictionary beliebig kürz- und erweiterbar
#         * ein Dictionary hat keine festen Indize, die Keys übernehmen die Funktion der Indexierung
#         * es besteht aus Schlüssel-Wertepaaren - Key-Value-Paaren/Pairs
#         * der Schlüssel steht vor dem Doppelpunkt, der Wert danach
#         * z.B. ein Schlüssel ist 'Guthaben', sein Wert ist 144.77
#         * die Schlüssel/Keys sind unique: kein Schlüssel kommt doppelt vor
#         * damit kann man Kategorien (= die Schlüssel) anlegen und diese mit Werten befüllen
#         * die Key-Value-Paare werden mit einem Komma getrennt
#         * ein Dictionary wird mit geschweiften Klammern definiert, z.B. ein leeres Dictionary: ``di = {}``
#     * <b>Tuple</b>
#         * Beispiele:
#             * ``tupl_example1 = (1, 2, 3)``
#             * ``tupl_example2 = ('Hi', 3.7, 8, 27)``
#         * wie eine Liste und ein Dictionary, kann ein Tuple (deutsch: Tupel) verschiedene Datentypen beinhalten
#         * im Gegensatz zu List und Dictionary ist ein Tuple unveränderlich - Werte können nicht ausgetauscht werden
#         * auch ein Tuple ist indexiert
#         * es wird genutzt, um Daten zu gruppieren
#         * die Daten/Werte werden mit einem Komma getrennt
#         * definiert wird es mit zwei runden Klammern, z.B. ein leeres Tuple: ``tupl = ()``
#     * <b>Set</b>
#         * Beispiele:
#             * ``set_example1 = {2, 1, 3}``
#             * ``set_example2 = {'Hi', (1, 2, 3), 'Ho', [True, False]}``
#         * wie die anderen Datenstrukturen kann ein Set verschiedene Datentypen beinhalten
#         * die Beispiele enthalten Integers, Strings, ein Tuple und eine Liste - alle Datentypen könnten vorkommen
#         * im Gegensatz zu den anderen Datenstrukturen (außer Dictionary-Keys) sind all seine Werte unique - kein Wert darf doppelt enthalten sein
#         * in Sets angelegte doppelte Werte werden von Python bei der Verarbeitung nicht berücksichtigt bzw. miteinander überschrieben
#         * ein Set ist nicht indexiert
#         * es wird eingesetzt, wenn man unique Werte braucht, die nicht geordnet sein müssen
#         * bei der Weiterverarbeitung wird die Einhaltung der Reihenfolge der Set-Elemente nicht gewährleistet - sie wird nicht erhalten bleiben
#         * Werte in einem Set werden auch mit einem Komma getrennt
#         * definiert wird es mit zwei geschweiften Klammern
#         * ein leeres Set wird über die Funktion ``set()`` definiert, z.B.: ``s = set()``
# <br>
# * **Spezielle List-Funktionen**
#     * ``.append()`` hängt das übergebene Element/Iterable ans Listenende an, z.B.: ``lst.append('Z')``
#         * <font color = green>lst.append(wert_ohne_datenstruktur)</font> ist äquivalent zu: <font color = green>lst[len(lst):&nbsp;] = einstelliges_iterable</font>
#         * hinzugefügte mehrstellige Iterables erscheinen mit ``.append()`` in der Liste als Substrukturen, z.B. als Subliste
#         * Beispiel:
#             * ``colors = ['Rot','Grün', 'Blau']``
#             * ``colors.append(['Orange', 'Lila'])`` => Output über ``print(colors)``: ['Rot', 'Grün', 'Blau', ['Orange', 'Lila']]
#     * **Überschreiben/Updaten** eines Listenelements an einem Index, z.B.: ``lst[0] = 1`` => überschreibt den Wert an Index 0 mit "1"
#     * ``.insert()`` zum Einfügen von Werten, inkl. Iterables, an einem bestimmten Index, z.B.: ``lst.insert(1,'Eins')`` => fügt "Eins" an Index 1 ein
#         * überschreibt **nicht** den vorherigen Wert am angegebenen Index
#         * Syntax: <font color = green>liste.insert(Index,Element)</font>
#         * die Angabe beider Parameter (Index und Element) ist ein Muss
#         * erzeugt Substrukturen der Iterables in der Liste
#         * Beispiel:
#             * ``colors = ['Rot','Grün', 'Blau']``
#             * ``colors.insert(2,['Orange', 'Lila'])`` => Output über ``print(colors)``: ['Rot', 'Grün', ['Orange', 'Lila'], 'Blau']
#     * ``.extend()`` zum Einfügen von Iterables
#         * fügt die Einträge der Iterables als gleichstufige Listeneinträge ein, ohne Substrukturen zu bilden
#         * Beispiel:
#             * ``colors = ['Rot','Grün', 'Blau']``
#             * ``colors.extend(['Orange', 'Lila'])`` => Output über ``print(colors)``: ['Rot','Grün', 'Blau', 'Orange', 'Lila']
#         * ist äquivalent zu: <font color = green>lst[len(lst):&nbsp;] = iterable</font>
#     * ``.remove()`` entfernt den ihm übergebenen Listeneintrag, z.B.: ``lst.remove(x)``
#         * entfernt den ersten auf den Übergabewert zutreffenden Listeneintrag und wirft bei nicht vorhandenen Einträgen einen <font color = darkred>ValueError</font>
#     * ``.pop()`` entfernt per default den letzten Listeneintrag, z.B.: ``lst.pop()``
#         * entfernt zusätzlich bei angegebenem Index dessen Wert, z.B.: ``lst.pop(1)`` => entfernt den Wert an Index 1
#         * ist äquivalent zu: ``del lst[1]``
#         * doch ``pop()`` zeigt im Gegensatz zu ``del`` den gelöschten Eintrag in der Ausgabe an
#     * ``.clear()`` zum Leeren der kompletten Liste, z.B.: ``lst.clear()`` => Output über ``print(lst)``: [&nbsp;]
#         * ist äquivalent zu: ``del lst[:]``
#     * ``.copy()`` zum Erstellen einer **flachen Kopie - shallow Copy -** der Liste, z.B.: ``lst_copy = lst.copy()``
#         * **anwendbar auch auf Dictionarys und Tuples, doch sonst auf keine weiteren Collection-Types und Iterables**
#         * eine flache Kopie beeinflusst das Original
#         * wird mit ``.copy()`` eine **flache Liste (ohne Subliste(n))** kopiert, ist das eine **tiefe Kopie**
#         * **aber** sobald eine **Liste Sublisten enthält (tiefe Liste)**, macht sich die grundsätzlich **flache Kopie** durch ``.copy()`` an den Sublisten-Werten bemerkbar
#         * Werte der Subliste werden **nicht** kopiert, lediglich die Adresse der Subliste wird stufengleich zu den Werten übergeben
#         * Äquivalent zu ``.copy()`` ist die Kopie mittels Slicing, z.B.: ``lst_copy = lst[:]``
#         * Erzeugung einer flachen Kopie auch über <b>=</b> möglich, z.B.: ``lst_copy = lst``
#             * die Listen liegen damit am gleichen Speicherort
#             * kopiert auch flache Listen flach
#             * Änderungen an Werten in Original und Kopie einer flachen Liste sind dann nicht unabhängig,  im Gegensatz zu ``lst_copy = lst[:]`` und ``lst_copy() = lst.copy()``
#     * ``copy.deeplist()`` erstellt eine **tiefe Kopie - deep Copy**
#         * ist eine Funktion des Moduls <b>copy</b>, deshalb vorher: ``import copy``
#         * **anwendbar auch auf Dictionarys und Tuples, doch sonst auf keine weiteren Collection-Types und Iterables**
#         * Änderungen an einer tiefen Kopie bewirken **keine Änderungen** am Original, auch nicht bei einer **tiefen Liste**
#         * bei Sublisten werden auch ihre Werte kopiert
#     * ``.reverse()`` zum Umdrehen einer Liste, z.B.: ``lst.rverse()`` => die Listeneinträge sind damit absteigend sortiert
#     * ``.count()`` zum Zählen eines übergebenen String-Wertes in der Liste, z.B.: ``lst.count('Rot')``
#         * die Häufigkeit von Werten an bestimmten Indizen zu suchen, ist mit Listen nicht möglich, nur mit Strings
#         * Syntax für Listen: <font color = green>lst.count(value)</font>
#     * ``.index()`` findet den Index des ihm übergebenen Wertes, z.B.: ``lst.index('Rot')``
#         * sucht von links nach rechts
#         * kommt der Wert mehrfach vor, zeigt ``.index()`` nur den erstgefundenen an
#         * optional kann man in einem bestimmten Bereich von Indizen suchen
#         * Syntax: <font color = green>lst.index(value,Start,Ende)</font>
#     * ``.sort()`` zum Sortieren von Listen, z.B.: ``lst.sort()``
#         * nicht zu verwechseln mit ``sorted()`` - **Unterschiede**:
#             * ``.sort()`` ist ein in-place Sortieralgorithmus, die Liste wird auf dem gleichen Speicherplatz überschrieben
#             * ``.sort()`` ist ein instabiler Sortieralgorithmus
#             * ``.sort()`` sortiert Listen, ``sorted()`` kann alle Iterables sortieren
#             * Rückgabewert von ``.sort()`` ist **None**, die übergebene Liste wird überschrieben - ``sorted()`` erzeugt immer eine Liste
#         * **Gemeinsamkeiten** von ``.sort()`` und ``sorted()``:
#             * sortieren in aufsteigender Reihenfolge - in <b>ascending Order</b>
#             * Werte müssen gleichen Datenyps sein, sonst kein Vergleich zum Sortieren möglich, doch Floats und Integers werden verglichen
#             * haben die zusätzlichen Parameter **key** und **reverse**
#         * neben seinen Schwächen hat ``.sort()`` den **Vorteil**, dass es effizient ist, weil keine neue Liste erstellt und Speicherplatz für diese freigegeben werden muss
#         * Syntax: <font color = green>lst.sort(key=None, reverse=False)</font>
#         * Anwendung einer Funktion mit ``.sort()`` (hier auch mit String möglich), z.B.: ``str.split().sort()``
#         * Anwendung einer Funktion mittels **key**, z.B.: ``lst.sort(key=len)`` => sortiert die Strings in der übergebenen Liste nach Länge
#         * Sortierung in absteigender Reihenfolge - in **descending Order** -  mit **reverse**, z.B.: ``lst.sort(reverse=True)``
#         * Sortierung nach Stringlänge und rückwärts, z.B.: ``lst.sort(liste, key=len, reverse=True)``
# <br>
# * **Verschachtelte Listen & verschachteltes Slicing**
#     * verschachtelte Listen werden auch tiefe Listen, nested Lists, Lists in Lists und Listen in Listen genannt
#     * pro Verschachtelungslevel wird ein eckiges Klammernpaar mehr zum Splitten eingesetzt
#     * das Slicing funktioniert wie gewohnt mit: <font color = green>lst[ab hier:bis vor diesen Index:step]</font>
#         * Beispiele:
#             * ``nums = [0, [0, 1, [0, 1, 2], 3, 4], 2, 3]``
#             * Ausgabe von **[[0, 1, [0, 1, 2], 3, 4], 2]** der Superliste: ``nums[1:3]``
#             * Ausgabe der **0** aus der ersten Subliste: ``nums[1][0]``
#             * Ausgabe der **2** aus der zweiten Subliste: ``nums[1][2][2]``
#             * Ausgabe der **3** aus der ersten Subliste: ``nums[1][3]``
#             * Ausgabe der **[0, 1]** aus der zweiten Subliste: ``nums[1][2][:2]``
#             * Ausgabe der **[3, 4]** aus der ersten Subliste: ``nums[1][-2:]``
#             * Ausgabe der **[0, 2]** aus der Superliste (Ausgabe in Zweierschritten): ``nums[::2]``
#             * Rückwärtsausgabe der zweiten Subliste (**[2, 1, 0]**): ``nums[1][2][::-1]``
# <br>
# * **Neue Listen aus Subsets erstellen**
#     * Subsets sind immer das Ergebnis des Splittens mit <b>[&nbsp;:&nbsp;]</b>
#     * eine flache Liste, die flach bleibt, kann über <b>=</b> aus einer gesplitteten Liste erstellt werden, z.B.: ``subset_lst = flat_lst[1:4]``
#     * bei tiefen Listen erhält man nur ein vom Original unabhängiges Subset, wenn das Subset tief kopiert wird
#         * Beispiel:
#             * zuvor: ``import copy``
#             * z.B.: ``subset_lst = copy.deepcopy(deep_list[1:4])``
# <br>
# * **Listen verbinden**
#     * heißt in der englischen Literatur <b>concatenating lists</b>
#     * mit ``+``, z.B.: ``new_lst = lst1 + lst2``
#         * Verbindung von mehr als 2 Lists möglich, z.B.: ``new_lst = lst1 + lst2 + lst3 + lst4``
#     * generell wird bei tiefen Listen für eine tiefe Kopie über das Modul <b>copy</b> die Funktion ``copy.deepcopy()`` hinzugefügt
#         * Beispiel: ``new_lst = copy.deepcopy(lst1 + lst2)``
#     * mit ``*``, z.B.: ``new_lst = [*lst1, *lst2]``
#         * Verbindung von mehr als 2 Lists möglich, z.B.: ``new_lst = [*lst1, *lst2, *lst3, *lst4]``
#     * mit ``.extend()``
#         * Beispiel 1 - lst1 <b>in-place</b> erweitern bzw. mit lst2 verbinden:
#             * ``lst1.extend(lst2)``
#         * Beispiel 2 - die verbundenen flachen Listen <b>auf einer anderen Adresse</b> speichern:
#             * ``lst1_2 = []``
#             * ``lst1_2 = lst1_2.extend(lst1 + lst2)``
#     * mit ``.list()`` Erstellung einer Liste aus <b>anderen Datenstrukturen</b>, z.B. Tupeln: ``new_lst = list(tuple1 + tuple2)``
#     * mit ``zip()`` => siehe "Funktionen für iterierbare Objekte" (oben)
# <br>
# * **Python**
#     * Python ist sowohl eine Interpreter- als auch eine Compiler-Sprache
#         * denn es übersetzt erst den Code in Maschinencode und führt ihn danach aus
#         * beides geschieht zur Laufzeit - der Ausführungszeit des Programms
#     * alles in Python ist ein Objekt und hat eine Adresse/Referenz
#     * Objekte sind Container für Werte - sie enthalten aber nicht die Werte, sondern die Adressen zu den Werten
#     * Die Werte sind immer der Inhalt, der mit ``==`` verglichen wird
#     * Adressen/Referenzen werden mit ``is`` verglichen
# <br>
# * **Python-Hilfe**
#     * Aufruf mit **Fragezeichen und ohne Funktionsklammern**, z.B.: ``sorted?``
#     * bei built-in Functions der Collection-Types mit der zugehörigen Datenstruktur, z.B.: ``list.sort?``
#     * weitere Hilfe über **help**, z.B.: ``help(sorted)``
#     * die **offizielle Python-Dokumentation**: https://docs.python.org/3/
# </div>
